# %%
import sys; sys.path.append('..')
from common.postgresql import PostgresConnector
db = PostgresConnector()
df = db.read_sql("SELECT * FROM cvm.cotas")
df

# %%
df_cda = db.read_sql('SELECT * FROM cvm.cda_fi_blc_2')

# %%
df_cda
