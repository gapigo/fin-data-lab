# %%
import sys; sys.path.append('..')
from common.postgresql import PostgresConnector
db = PostgresConnector()
df = db.read_sql("SELECT * FROM fi_cad_fi")

# %%
print('a')
df

# %%
-136319282.5 + 95955163.63999891 -13572455.010000005
# Out:
# -53936573.87000109

# %%
260216.00999999998+234474857.98+22724345.390000004
# Out:
# 257459419.38

# %%
0.0
175793334.4599986
-207337327.12
